# %% [markdown]
#  # Questions:
#
#  1. Is there any strong or weak correlation between rainfall & price of onion & Tomato ?
#  2. Is there any differences of price between states / Regions?
#  3. Is there any other factors apart from rainfall on the price of onion & Tomato?
#  4. How to analyse the supply & demand and decide which crop to harvest as a farmer?
#  5. which region is the best place to sell?
#  6. Average price of Onions is 1300. Prove it with 95% confidence level

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
import scipy.stats as stats

# %%
data=pd.read_csv('Onion_weekly.csv')

# %%
data
# Out:
#      Year  CW  Bangalore_Price  Delhi_Price  Hyderabad_Price  Kolkata_Price  \
# 0    2015   1             1200         1462             1125         1967.0
# 1    2015   2             1359         1383             1260         1596.0
# 2    2015   3             1208         1256              906         1771.0
# 3    2015   4             1352         1321             1130         1625.0
# 4    2015   5             1323         1412             1400         1750.0
# ..    ...  ..              ...          ...              ...            ...
# 153  2017  48             3880         2685             3279         4625.0
# 154  2017  49             3270         2557             2593            NaN
# 155  2017  50             3354         2825             2867            NaN
# 156  2017  51             2958         2820             2900            NaN
# 157  2017  52             3030         2750             2480            NaN
#
#      Pune_Price  Karnataka  Delhi  Andrapradesh  Westbengal  Maharashtra
# 0          1175        5.5   12.4          21.4        28.6         37.8
# 1          1290        5.5   12.4          21.4        28.6         37.8
# 2          1167        5.5   12.4          21.4        28.6         37.8
# 3          1150        5.5   12.4          21.4        28.6         37.8
# 4          1120        5.5   12.4          21.4        28.6         37.8
# ..          ...        ...    ...           ...         ...          ...
# 153        2767       38.1    1.8          81.9        25.7          7.7
# 154        2217       15.8    4.2           8.6        15.0          7.8
# 155        2100       15.8    4.2           8.6        15.0          7.8
# 156        2033       15.8    4.2           8.6        15.0          7.8
# 157        2040       15.8    4.2           8.6        15.0          7.8
#
# [158 rows x 12 columns]

# %% [markdown]
# step 1: describe the data
# Step 2 : plot the data with histogram, box plot, cross plot, heatmap (pearson correlation)
# step 3 : check whether the data is normal and variances are equal and decide what tests can be done based on the questions (1 sample z test or t-test) - hypothesis testing
# step 4 : Simulation
# step 5 : Conclude with the suggestions based on test results

# %%
data.shape
# Out:
# (158, 12)

# %%
data.dtypes
# Out:
# Year                 int64
# CW                   int64
# Bangalore_Price      int64
# Delhi_Price          int64
# Hyderabad_Price      int64
# Kolkata_Price      float64
# Pune_Price           int64
# Karnataka          float64
# Delhi              float64
# Andrapradesh       float64
# Westbengal         float64
# Maharashtra        float64
# dtype: object

# %%
data['Year']=data['Year'].astype('object',copy='False')
data['CW']=data['CW'].astype('object',copy='False')

# %%
data.dtypes
# Out:
# Year                object
# CW                  object
# Vegetable           object
# Bangalore Price      int64
# Delhi Price          int64
# Hyderabad Price      int64
# Kolkata Price      float64
# Pune Price           int64
# Karnataka          float64
# Delhi              float64
# Andra Pradesh      float64
# West bengal        float64
# Maharashtra        float64
# dtype: object

# %% [markdown]
# # description of the data

# %%
data.describe()
# Out:
#               Year          CW  Bangalore_Price  Delhi_Price  Hyderabad_Price  \
# count   158.000000  158.000000       158.000000   158.000000       158.000000
# mean   2015.993671   26.835443      1305.702532  1352.417722      1228.582278
# std       0.817771   15.252800       804.636671   823.491380       917.682648
# min    2015.000000    1.000000       545.000000   596.000000       321.000000
# 25%    2015.000000   14.000000       719.500000   737.500000       619.000000
# 50%    2016.000000   27.000000       988.000000  1093.000000       931.500000
# 75%    2017.000000   40.000000      1585.250000  1603.750000      1477.250000
# max    2017.000000   53.000000      3880.000000  4232.000000      4825.000000
#
#        Kolkata_Price   Pune_Price    Karnataka       Delhi  Andrapradesh  \
# count     151.000000   158.000000   158.000000  158.000000    158.000000
# mean     1911.529801  1468.360759   353.740506   33.072152    211.340506
# std      1139.755400  1133.007211   401.908934   43.551593    213.064083
# min       580.000000   400.000000     0.000000    0.000000      0.000000
# 25%      1091.500000   719.000000    20.400000    1.925000     20.800000
# 50%      1435.000000   998.000000   203.500000   10.300000     97.100000
# 75%      2369.000000  1771.250000   614.300000   43.700000    451.700000
# max      5533.000000  5467.000000  1272.100000  159.800000    651.500000
#
#         Westbengal  Maharashtra
# count   158.000000   158.000000
# mean    326.310127   201.808861
# std     344.826656   265.100432
# min       0.300000     0.000000
# 25%      28.600000     7.725000
# 50%     172.600000    38.000000
# 75%     591.100000   457.100000
# max    1066.800000  1085.900000

# %%
from matplotlib import gridspec
plt.rcParams['figure.figsize'] = [15,10]
gs = gridspec.GridSpec(3, 3, width_ratios=[2.5, 2.5, 2.5], height_ratios=[.20, .10, .15])
a1 = plt.subplot(gs[0, 0])
a1.set_title("Bangalore Price Distribution", fontsize=15)
a1=sns.distplot(data.Bangalore_Price)

a2 = plt.subplot(gs[1, 0])
a2= sns.boxplot(data.Bangalore_Price)

plt.show()

# %%
plt.rcParams['figure.figsize'] = [15,3]
plt.figure(10)
data_onion=data[data['Vegetable']=='Onion']
plt.plot(data_onion['CW'] ,data_onion['Bangalore_Price'])

# %%
corr = data.corr()
corr
# Out:
#                      Year        CW  Bangalore_Price  Delhi_Price  \
# Year             1.000000 -0.013361        -0.141910    -0.357564
# CW              -0.013361  1.000000         0.413617     0.365274
# Bangalore_Price -0.141910  0.413617         1.000000     0.918511
# Delhi_Price     -0.357564  0.365274         0.918511     1.000000
# Hyderabad_Price -0.278221  0.361279         0.923425     0.966673
# Kolkata_Price   -0.319125  0.433638         0.942094     0.957481
# Pune_Price      -0.379837  0.437510         0.834583     0.943223
# Karnataka        0.006287  0.226821         0.164577     0.136086
# Delhi           -0.011969  0.016040         0.035333     0.017023
# Andrapradesh    -0.040429  0.385913         0.252333     0.245488
# Westbengal       0.032029  0.171300         0.137691     0.091247
# Maharashtra      0.051163  0.229990         0.092358     0.064200
#
#                  Hyderabad_Price  Kolkata_Price  Pune_Price  Karnataka  \
# Year                   -0.278221      -0.319125   -0.379837   0.006287
# CW                      0.361279       0.433638    0.437510   0.226821
# Bangalore_Price         0.923425       0.942094    0.834583   0.164577
# Delhi_Price             0.966673       0.957481    0.943223   0.136086
# Hyderabad_Price         1.000000       0.942493    0.916628   0.168034
# Kolkata_Price           0.942493       1.000000    0.947758   0.228054
# Pune_Price              0.916628       0.947758    1.000000   0.202971
# Karnataka               0.168034       0.228054    0.202971   1.000000
# Delhi                   0.048344       0.031685    0.018591   0.734313
# Andrapradesh            0.278448       0.359958    0.344618   0.829760
# Westbengal              0.139361       0.166121    0.134672   0.921846
# Maharashtra             0.111668       0.141726    0.104818   0.837774
#
#                     Delhi  Andrapradesh  Westbengal  Maharashtra
# Year            -0.011969     -0.040429    0.032029     0.051163
# CW               0.016040      0.385913    0.171300     0.229990
# Bangalore_Price  0.035333      0.252333    0.137691     0.092358
# Delhi_Price      0.017023      0.245488    0.091247     0.064200
# Hyderabad_Price  0.048344      0.278448    0.139361     0.111668
# Kolkata_Price    0.031685      0.359958    0.166121     0.141726
# Pune_Price       0.018591      0.344618    0.134672     0.104818
# Karnataka        0.734313      0.829760    0.921846     0.837774
# Delhi            1.000000      0.503488    0.751791     0.736726
# Andrapradesh     0.503488      1.000000    0.802262     0.832191
# Westbengal       0.751791      0.802262    1.000000     0.882472
# Maharashtra      0.736726      0.832191    0.882472     1.000000

# %%
fig,ax = plt.subplots(figsize=(20, 20))
sns.heatmap(corr, annot = True, linewidths = 0.05, vmin = -1 , vmax = 1, cmap = "YlGnBu" , fmt = '10.4f')
plt.show()
